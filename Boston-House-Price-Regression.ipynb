# %% [markdown]
# <a href="https://www.kaggle.com/code/danuherath/boston-house-price-regression?scriptVersionId=201507015" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# <h1 align="center"> Boston House Prices Prediction (Regression) </h1>
#
# <img
#     src="https://storage.googleapis.com/kaggle-datasets-images/4657107/7924328/38e0b60f5d62e37ed21107cc39184d1b/dataset-cover.jpeg?t=2024-03-23-17-41-41"
#     alt=""
#     width="400"
#     height="300"
#     style="display: block; margin: 0 auto; border-radius:15px"
# />
#
# ---

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error as MAE, mean_squared_error as MSE
# %matplotlib inline

# %%
data = pd.read_csv('/kaggle/input/the-boston-housing-dataset/Boston (1).csv')
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS     NX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
data.shape
# Out:
# (506, 14)

# %% [markdown]
# ---
# # Data Visualization
# ---

# %%
corr = data.corr()
cmap = sns.light_palette("darkgreen", as_cmap=True)

plt.figure(figsize=(10,8))
sns.heatmap(corr, annot=True, cmap=cmap, linewidths=0.2)

plt.title('Boston Houses Dataset Feature Correlations', fontsize=16)

plt.savefig('Boston Houses dataset feature correlations.svg')
plt.show()

# %% [markdown]
# ---
# # Model Training
# ---

# %%
X = data.drop(columns=['MEDV'])
y = data['MEDV']

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
regression_model = LinearRegression()
regression_model.fit(X_train, y_train)
y_pred = regression_model.predict(X_val)

# %%
print (f"Mean Absolute Error: {MAE(y_val, y_pred)}")
print (f"Mean Squared Error: {MSE(y_val, y_pred)}")
print (f"Root Mean Squared Error: {np.sqrt(MSE(y_val, y_pred))}")
# Out:
# Mean Absolute Error: 3.7507121808389083
# Mean Squared Error: 23.380836480270197
# Root Mean Squared Error: 4.835373458200535
